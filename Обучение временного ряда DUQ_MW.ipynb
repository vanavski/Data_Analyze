# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import warnings
from itertools import product

def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # О чем данные: расчетное потребление энергии в мегаваттах (МВт) каждый час. Данные подготовленны Duquesne Light Holdings, Inc. Энергия измерялась в Пенсильвании.

# %% [markdown]
# ## Необработанные данные

# %%
db = 'DUQ_hourly.csv'
df = pd.read_csv(db, index_col=['Datetime'], parse_dates=['Datetime'], dayfirst=True)
df
# Out:
#                      DUQ_MW
# Datetime
# 2005-12-31 01:00:00  1458.0
# 2005-12-31 02:00:00  1377.0
# 2005-12-31 03:00:00  1351.0
# 2005-12-31 04:00:00  1336.0
# 2005-12-31 05:00:00  1356.0
# ...                     ...
# 2018-01-01 20:00:00  1962.0
# 2018-01-01 21:00:00  1940.0
# 2018-01-01 22:00:00  1891.0
# 2018-01-01 23:00:00  1820.0
# 2018-01-02 00:00:00  1721.0
#
# [119068 rows x 1 columns]

# %%
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel('sales')
pylab.show()

# %%
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# ## Преобразуем по неделям

# %%
db = 'DUQ_hourly.csv'
df = pd.read_csv(db)
df["Datetime"] = pd.to_datetime(df["Datetime"])
df
# Out:
#                   Datetime  DUQ_MW
# 0      2005-12-31 01:00:00  1458.0
# 1      2005-12-31 02:00:00  1377.0
# 2      2005-12-31 03:00:00  1351.0
# 3      2005-12-31 04:00:00  1336.0
# 4      2005-12-31 05:00:00  1356.0
# ...                    ...     ...
# 119063 2018-01-01 20:00:00  1962.0
# 119064 2018-01-01 21:00:00  1940.0
# 119065 2018-01-01 22:00:00  1891.0
# 119066 2018-01-01 23:00:00  1820.0
# 119067 2018-01-02 00:00:00  1721.0
#
# [119068 rows x 2 columns]

# %%
df['date_minus_time'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date_minus_time"],inplace=True)
df
# Out:
#                            Datetime  DUQ_MW date_minus_time
# date_minus_time
# 2005-12-31      2005-12-31 01:00:00  1458.0      2005-12-31
# 2005-12-31      2005-12-31 02:00:00  1377.0      2005-12-31
# 2005-12-31      2005-12-31 03:00:00  1351.0      2005-12-31
# 2005-12-31      2005-12-31 04:00:00  1336.0      2005-12-31
# 2005-12-31      2005-12-31 05:00:00  1356.0      2005-12-31
# ...                             ...     ...             ...
# 2018-01-01      2018-01-01 20:00:00  1962.0      2018-01-01
# 2018-01-01      2018-01-01 21:00:00  1940.0      2018-01-01
# 2018-01-01      2018-01-01 22:00:00  1891.0      2018-01-01
# 2018-01-01      2018-01-01 23:00:00  1820.0      2018-01-01
# 2018-01-02      2018-01-02 00:00:00  1721.0      2018-01-02
#
# [119068 rows x 3 columns]

# %%
df = df.resample('W', on = 'date_minus_time').sum()
df
# Out:
#                    DUQ_MW
# date_minus_time
# 2005-01-02        64069.0
# 2005-01-09       273052.0
# 2005-01-16       274529.0
# 2005-01-23       301980.0
# 2005-01-30       297042.0
# ...                   ...
# 2018-07-08       323737.0
# 2018-07-15       322957.0
# 2018-07-22       307617.0
# 2018-07-29       301925.0
# 2018-08-05       167208.0
#
# [710 rows x 1 columns]

# %%
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel('sales')
pylab.show()

# %%
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.000000

# %%
df['DUQ_MW'], lmbda = stats.boxcox(df['DUQ_MW'])
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel(u'Transformed wine sales')
print("Оптимальный параметр преобразования Кокса- Бокса: %f" % lmbda)
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
# Оптимальный параметр преобразования Кокса- Бокса: 0.976499
#  Критерий Дики-Фуллера: p=0.000000

# %%
plt.figure(figsize(15,8))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df['DUQ_MW'][13:].values.squeeze(), lags=48, ax=ax)
pylab.show()
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df['DUQ_MW'][13:].values.squeeze(), lags=48, ax=ax)
pylab.show()

# %% [markdown]
# В автокоррекции номер последнего значимого сезонного лага Q = 4
#
# Номер не сезонного значимого лага  q = 11
#
# В частичной автокоррекции номер последнего значимого сезонного лага P = 4
#
# Номер не сезонного значимого лага p = 10

# %%
Qs = range(0, 5)
qs = range(0, 12)
Ps = range(0, 5)
ps = range(0, 11)
D = 1
d = 1

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 3300

# %%
# %%time
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучаетс¤
    try:
        model=sm.tsa.statespace.SARIMAX(df['DUQ_MW'], order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохран¤ем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     480                                            full_output=full_output,
#     481                                            disp=disp, callback=callback,
# --> 482                                            skip_hessian=True, **kwargs)
#     483
#     484         # Just return the fitted parameters if requested
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# D:\Programs\anaconda\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# D:\Programs\anaconda\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# D:\Programs\anaconda\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# D:\Programs\anaconda\lib\site-packages\scipy\optimize\optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     694         ei[k] = 1.0
#     695         d = epsilon * ei
# --> 696         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     697         ei[k] = 0.0
#     698     return grad
#
# D:\Programs\anaconda\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     652             params = self.transform_params(params)
#     653
# --> 654         self.update(params, transformed=True, complex_step=complex_step)
#     655
#     656         if complex_step:
#
# D:\Programs\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in update(self, params, transformed, complex_step)
#    1568         if self.k_seasonal_ar > 0:
#    1569             reduced_polynomial_ar = -np.polymul(
# -> 1570                 self._polynomial_ar, self._polynomial_seasonal_ar
#    1571             )
#    1572         else:
#
# D:\Programs\anaconda\lib\site-packages\numpy\lib\polynomial.py in polymul(a1, a2)
#     899     truepoly = (isinstance(a1, poly1d) or isinstance(a2, poly1d))
#     900     a1, a2 = poly1d(a1), poly1d(a2)
# --> 901     val = NX.convolve(a1, a2)
#     902     if truepoly:
#     903         val = poly1d(val)
#
# D:\Programs\anaconda\lib\site-packages\numpy\core\numeric.py in convolve(a, v, mode)
#    1112         raise ValueError('v cannot be empty')
#    1113     mode = _mode_from_name(mode)
# -> 1114     return multiarray.correlate(a, v[::-1], mode)
#    1115
#    1116
#
# KeyboardInterrupt:

# %%
#сохранить в файл результаты
results
# Out:
# [[(0, 0, 0, 0), 16065.7593382717],
#  [(0, 0, 0, 1), 15585.537634690667],
#  [(0, 0, 0, 2), 15619.386875150705],
#  [(0, 0, 0, 3), 15586.842977583865],
#  [(0, 0, 0, 4), 15632.194511258127],
#  [(0, 0, 1, 0), 15802.039514059417],
#  [(0, 0, 1, 1), 15595.747726747002],
#  [(0, 0, 1, 2), 15589.373959163513],
#  [(0, 0, 1, 3), 15593.981509638255],
#  [(0, 0, 1, 4), 15593.943980702848],
#  [(0, 0, 2, 0), 15730.950652402196],
#  [(0, 0, 2, 1), 15593.636513796155],
#  [(0, 0, 2, 2), 15589.258886389205],
#  [(0, 0, 2, 3), 15590.653871436414],
#  [(0, 0, 2, 4), 15586.909171738323],
#  [(0, 0, 3, 0), 15670.058390785936],
#  [(0, 0, 3, 1), 15586.068266159062],
#  [(0, 0, 3, 2), 15587.236614281617],
#  [(0, 0, 3, 3), 15584.622262781082],
#  [(0, 0, 3, 4), 15585.147739304626],
#  [(0, 0, 4, 0), 15635.013607974479],
#  [(0, 0, 4, 1), 15584.695186577603],
#  [(0, 0, 4, 2), 15586.135742888824],
#  [(0, 0, 4, 3), 15585.65675513735],
#  [(0, 0, 4, 4), 15581.178570539552],
#  [(0, 1, 0, 0), 16046.979519258824],
#  [(0, 1, 0, 1), 15539.831121207691],
#  [(0, 1, 0, 2), 15658.326046869914],
#  [(0, 1, 0, 3), 15659.718689810066],
#  [(0, 1, 0, 4), 15659.88622262678],
#  [(0, 1, 1, 0), 15767.612638067516],
#  [(0, 1, 1, 1), 15657.732342827578],
#  [(0, 1, 1, 2), 15657.217191950747],
#  [(0, 1, 1, 3), 15659.214102741375],
#  [(0, 1, 1, 4), 15660.080856916156],
#  [(0, 1, 2, 0), 15732.278984933648],
#  [(0, 1, 2, 1), 15658.976171840804],
#  [(0, 1, 2, 2), 15659.214728026553],
#  [(0, 1, 2, 3), 15647.138957668703],
#  [(0, 1, 2, 4), 15649.018236133319],
#  [(0, 1, 3, 0), 15691.486744178928],
#  [(0, 1, 3, 1), 15658.710475127333],
#  [(0, 1, 3, 2), 15660.091777948208],
#  [(0, 1, 3, 3), 15661.881986182569],
#  [(0, 1, 3, 4), 15663.864658934657],
#  [(0, 1, 4, 0), 15678.469479472626],
#  [(0, 1, 4, 1), 15659.57433601463],
#  [(0, 1, 4, 2), 15661.351654486196],
#  [(0, 1, 4, 3), 15663.84393575802],
#  [(0, 1, 4, 4), 15664.697352590792],
#  [(0, 2, 0, 0), 16045.105968451177],
#  [(0, 2, 0, 1), 15663.51656989626],
#  [(0, 2, 0, 2), 15659.710543757883],
#  [(0, 2, 0, 3), 15661.14962517344],
#  [(0, 2, 0, 4), 15661.468895141514],
#  [(0, 2, 1, 0), 15769.325940156807],
#  [(0, 2, 1, 1), 15659.167091230502],
#  [(0, 2, 1, 2), 15658.803936190718],
#  [(0, 2, 1, 3), 15660.798699661404],
#  [(0, 2, 1, 4), 15661.700390886268],
#  [(0, 2, 2, 0), 15733.69618388106],
#  [(0, 2, 2, 1), 15660.480844364844],
#  [(0, 2, 2, 2), 15660.799811859722],
#  [(0, 2, 2, 3), 15648.600901360234],
#  [(0, 2, 2, 4), 15650.488642860291],
#  [(0, 2, 3, 0), 15693.127282435518],
#  [(0, 2, 3, 1), 15660.333837156722],
#  [(0, 2, 3, 2), 15661.711271499953],
#  [(0, 2, 3, 3), 15663.496945323255],
#  [(0, 2, 3, 4), 15665.485895103078],
#  [(0, 2, 4, 0), 15680.13696867688],
#  [(0, 2, 4, 1), 15661.191502750406],
#  [(0, 2, 4, 2), 15662.97578208872],
#  [(0, 2, 4, 3), 15651.550384820177],
#  [(0, 2, 4, 4), 15665.810946221196],
#  [(0, 3, 0, 0), 16045.82076468012],
#  [(0, 3, 0, 1), 15658.81924955371],
#  [(0, 3, 0, 2), 15655.109657808076],
#  [(0, 3, 0, 3), 15656.683110386151],
#  [(0, 3, 0, 4), 15657.084773031473],
#  [(0, 3, 1, 0), 15766.19128357599],
#  [(0, 3, 1, 1), 15654.654836237678],
#  [(0, 3, 1, 2), 15654.460060047],
#  [(0, 3, 1, 3), 15656.452382644607],
#  [(0, 3, 1, 4), 15657.335656224423],
#  [(0, 3, 2, 0), 15731.026251975274],
#  [(0, 3, 2, 1), 15656.098960533815],
#  [(0, 3, 2, 2), 15656.45403356796],
#  [(0, 3, 2, 3), 15643.649650682602],
#  [(0, 3, 2, 4), 15645.561448086359],
#  [(0, 3, 3, 0), 15689.626735299655],
#  [(0, 3, 3, 1), 15655.971535683806],
#  [(0, 3, 3, 2), 15657.34022077504],
#  [(0, 3, 3, 3), 15659.126298579065],
#  [(0, 3, 3, 4), 15661.113596860641],
#  [(0, 3, 4, 0), 15676.3213736262],
#  [(0, 3, 4, 1), 15656.810368267557],
#  [(0, 3, 4, 2), 15658.591933747983],
#  [(0, 3, 4, 3), 15647.338488477344],
#  [(0, 3, 4, 4), 15663.105512367172],
#  [(0, 4, 0, 0), 16046.051218170625],
#  [(0, 4, 0, 1), 15660.22828536163],
#  [(0, 4, 0, 2), 15656.591726437944],
#  [(0, 4, 0, 3), 15658.169697023313],
#  [(0, 4, 0, 4), 15658.572044214412],
#  [(0, 4, 1, 0), 15767.874060015145],
#  [(0, 4, 1, 1), 15656.142146983382],
#  [(0, 4, 1, 2), 15655.929161959228],
#  [(0, 4, 1, 3), 15657.922405911759],
#  [(0, 4, 1, 4), 15658.768339166854],
#  [(0, 4, 2, 0), 15732.521526102728],
#  [(0, 4, 2, 1), 15657.588491894398],
#  [(0, 4, 2, 2), 15657.923876011513],
#  [(0, 4, 2, 3), 15644.70157833728],
#  [(0, 4, 2, 4), 15646.632684468392],
#  [(0, 4, 3, 0), 15691.0331398461],
#  [(0, 4, 3, 1), 15657.438637300213],
#  [(0, 4, 3, 2), 15658.781283088687],
#  [(0, 4, 3, 3), 15660.542503922767],
#  [(0, 4, 3, 4), 15662.535224093219],
#  [(0, 4, 4, 0), 15677.826467250983],
#  [(0, 4, 4, 1), 15658.228796382113],
#  [(0, 4, 4, 2), 15660.021317822011],
#  [(0, 4, 4, 3), 15647.643393483573],
#  [(0, 4, 4, 4), 15664.533839473574],
#  [(0, 5, 0, 0), 16041.445186298237],
#  [(0, 5, 0, 1), 15666.011858108055],
#  [(0, 5, 0, 2), 15662.830015839005],
#  [(0, 5, 0, 3), 15664.430052723375],
#  [(0, 5, 0, 4), 15664.925654587056],
#  [(0, 5, 1, 0), 15771.799087642321],
#  [(0, 5, 1, 1), 15662.418901360503],
#  [(0, 5, 1, 2), 15662.31068419445],
#  [(0, 5, 1, 3), 15664.305616365276],
#  [(0, 5, 1, 4), 15665.215289095784],
#  [(0, 5, 2, 0), 15736.9570359774],
#  [(0, 5, 2, 1), 15663.892980500143],
#  [(0, 5, 2, 2), 15664.3066792873],
#  [(0, 5, 2, 3), 15651.610262599055],
#  [(0, 5, 2, 4), 15653.45365431728],
#  [(0, 5, 3, 0), 15696.745459739317],
#  [(0, 5, 3, 1), 15663.86581229507],
#  [(0, 5, 3, 2), 15665.226002776006],
#  [(0, 5, 3, 3), 15666.996913133997],
#  [(0, 5, 3, 4), 15668.986816240344],
#  [(0, 5, 4, 0), 15683.844153287644],
#  [(0, 5, 4, 1), 15664.67591331818],
#  [(0, 5, 4, 2), 15666.469494255478],
#  [(0, 5, 4, 3), 15654.485913214165],
#  [(0, 5, 4, 4), 15670.980947578186],
#  [(0, 6, 0, 0), 15975.351351396333],
#  [(0, 6, 0, 1), 15651.649542045241],
#  [(0, 6, 0, 2), 15648.35850484216],
#  [(0, 6, 0, 3), 15649.931270360892],
#  [(0, 6, 0, 4), 15650.352180594438],
#  [(0, 6, 1, 0), 15763.546501672947],
#  [(0, 6, 1, 1), 15647.932214743632],
#  [(0, 6, 1, 2), 15647.69408173849],
#  [(0, 6, 1, 3), 15649.69084984512],
#  [(0, 6, 1, 4), 15650.532998885843],
#  [(0, 6, 2, 0), 15726.599038504384],
#  [(0, 6, 2, 1), 15649.369148642596],
#  [(0, 6, 2, 2), 15649.691460978962],
#  [(0, 6, 2, 3), 15636.013112082092],
#  [(0, 6, 2, 4), 15637.91167399783],
#  [(0, 6, 3, 0), 15684.4037356265],
#  [(0, 6, 3, 1), 15649.237842804327],
#  [(0, 6, 3, 2), 15650.548347254095],
#  [(0, 6, 3, 3), 15652.299521858386],
#  [(0, 6, 3, 4), 15654.288265155523],
#  [(0, 6, 4, 0), 15670.5567568253],
#  [(0, 6, 4, 1), 15649.949066985333],
#  [(0, 6, 4, 2), 15651.722751610549],
#  [(0, 6, 4, 3), 15639.305086299582],
#  [(0, 6, 4, 4), 15655.535931088269],
#  [(0, 7, 0, 0), 15986.217051441297],
#  [(0, 7, 0, 1), 15643.714369749834],
#  [(0, 7, 0, 2), 15639.73951703084],
#  [(0, 7, 0, 3), 15641.227613738298],
#  [(0, 7, 0, 4), 15641.510669359974],
#  [(0, 7, 1, 0), 15757.470248515316],
#  [(0, 7, 1, 1), 15639.233767940183],
#  [(0, 7, 1, 2), 15638.93819460231],
#  [(0, 7, 1, 3), 15640.932294398439],
#  [(0, 7, 1, 4), 15641.850874662907],
#  [(0, 7, 2, 0), 15720.061799896082],
#  [(0, 7, 2, 1), 15640.590862509149],
#  [(0, 7, 2, 2), 15640.933520168357],
#  [(0, 7, 2, 3), 15627.855415686314],
#  [(0, 7, 2, 4), 15629.815222545061],
#  [(0, 7, 3, 0), 15677.536639871747],
#  [(0, 7, 3, 1), 15640.444296789992],
#  [(0, 7, 3, 2), 15641.853651234727],
#  [(0, 7, 3, 3), 15643.687039505541],
#  [(0, 7, 3, 4), 15644.518470319334],
#  [(0, 7, 4, 0), 15662.940535249638],
#  [(0, 7, 4, 1), 15641.368478476576],
#  [(0, 7, 4, 2), 15643.146820188735],
#  [(0, 7, 4, 3), 15645.636997004622],
#  [(0, 7, 4, 4), 15646.519618464725],
#  [(0, 8, 0, 0), 15983.971154711602],
#  [(0, 8, 0, 1), 15644.134047547725],
#  [(0, 8, 0, 2), 15640.192740910687],
#  [(0, 8, 0, 3), 15641.650260328344],
#  [(0, 8, 0, 4), 15641.906364710363],
#  [(0, 8, 1, 0), 15758.462413834688],
#  [(0, 8, 1, 1), 15639.669418256208],
#  [(0, 8, 1, 2), 15639.264545425616],
#  [(0, 8, 1, 3), 15641.261209686978],
#  [(0, 8, 1, 4), 15642.177669234556],
#  [(0, 8, 2, 0), 15720.835109880949],
#  [(0, 8, 2, 1), 15640.980391986812],
#  [(0, 8, 2, 2), 15641.261854277334],
#  [(0, 8, 2, 3), 15627.333351463745],
#  [(0, 8, 2, 4), 15629.082619653589],
#  [(0, 8, 3, 0), 15678.140091992664],
#  [(0, 8, 3, 1), 15640.80118262175],
#  [(0, 8, 3, 2), 15642.192649808763],
#  [(0, 8, 3, 3), 15644.008301836719],
#  [(0, 8, 3, 4), 15645.993147913727],
#  [(0, 8, 4, 0), 15663.535290351709],
#  [(0, 8, 4, 1), 15641.706397073645],
#  [(0, 8, 4, 2), 15643.494729158461],
#  [(0, 8, 4, 3), 15631.795914581973],
#  [(0, 8, 4, 4), 15646.339210170107],
#  [(0, 9, 0, 0), 15956.088211818997],
#  [(0, 9, 0, 1), 15636.473927723748],
#  [(0, 9, 0, 2), 15632.904528191406],
#  [(0, 9, 0, 3), 15634.539658188267],
#  [(0, 9, 0, 4), 15635.08392015049],
#  [(0, 9, 1, 0), 15750.818488068311],
#  [(0, 9, 1, 1), 15632.514498088838],
#  [(0, 9, 1, 2), 15632.629007285563],
#  [(0, 9, 1, 3), 15634.613298986062],
#  [(0, 9, 1, 4), 15635.587346116503],
#  [(0, 9, 2, 0), 15713.618030884496],
#  [(0, 9, 2, 1), 15634.067116377166],
#  [(0, 9, 2, 2), 15634.616633911803],
#  [(0, 9, 2, 3), 15623.695843111389],
#  [(0, 9, 2, 4), 15624.673959229225],
#  [(0, 9, 3, 0), 15671.049962906609],
#  [(0, 9, 3, 1), 15634.168590276618],
#  [(0, 9, 3, 2), 15635.579984375989],
#  [(0, 9, 3, 3), 15637.403922508303],
#  [(0, 9, 3, 4), 15639.39391934099],
#  [(0, 9, 4, 0), 15656.708515723876],
#  [(0, 9, 4, 1), 15635.094406980983],
#  [(0, 9, 4, 2), 15636.88096436952],
#  [(0, 9, 4, 3), 15625.804111966474],
#  [(0, 9, 4, 4), 15639.806278959812],
#  [(0, 10, 0, 0), 15913.061757268335],
#  [(0, 10, 0, 1), 15637.88756597749],
#  [(0, 10, 0, 2), 15634.55303522263],
#  [(0, 10, 0, 3), 15636.322909500619],
#  [(0, 10, 0, 4), 15637.056300712618],
#  [(0, 10, 1, 0), 15750.493847314385],
#  [(0, 10, 1, 1), 15634.260920652],
#  [(0, 10, 1, 2), 15634.81925865349],
#  [(0, 10, 1, 3), 15636.772058182196],
#  [(0, 10, 1, 4), 15637.819041918468],
#  [(0, 10, 2, 0), 15713.131490929074],
#  [(0, 10, 2, 1), 15635.980483617464],
#  [(0, 10, 2, 2), 15636.782174239652],
#  [(0, 10, 2, 3), 15638.819347721586],
#  [(0, 10, 2, 4), 15628.627880519825],
#  [(0, 10, 3, 0), 15672.518566614584],
#  [(0, 10, 3, 1), 15636.272521584253],
#  [(0, 10, 3, 2), 15637.78359016034],
#  [(0, 10, 3, 3), 15639.674263315876],
#  [(0, 10, 3, 4), 15641.652542718668],
#  [(0, 10, 4, 0), 15658.325817468289],
#  [(0, 10, 4, 1), 15637.391375050636],
#  [(0, 10, 4, 2), 15639.166422816532],
#  [(0, 10, 4, 3), 15630.197756630372],
#  [(0, 10, 4, 4), 15641.37818469132],
#  [(0, 11, 0, 0), 15839.829019016226],
#  [(0, 11, 0, 1), 15642.187078442847],
#  [(0, 11, 0, 2), 15640.109555787736],
#  [(0, 11, 0, 3), 15641.935917743358],
#  [(0, 11, 0, 4), 15642.81631114073],
#  [(0, 11, 1, 0), 15748.470686139837],
#  [(0, 11, 1, 1), 15639.898017574602],
#  [(0, 11, 1, 2), 15640.649210686026],
#  [(0, 11, 1, 3), 15642.613173919151],
#  [(0, 11, 1, 4), 15643.737902616072],
#  [(0, 11, 2, 0), 15713.909939323476],
#  [(0, 11, 2, 1), 15641.675193159172],
#  [(1, 6, 4, 1), 15648.347800703763],
#  [(1, 6, 4, 2), 15650.082914589126],
#  [(1, 6, 4, 3), 15641.59950478534],
#  [(1, 6, 4, 4), 15644.025823146785],
#  [(1, 7, 0, 0), 15923.76160987803],
#  [(1, 7, 0, 1), 15637.935142449078],
#  [(1, 7, 0, 2), 15637.173465148699],
#  [(1, 7, 0, 3), 15639.0466994284],
#  [(1, 7, 0, 4), 15639.934972852912],
#  [(1, 7, 1, 0), 15743.478710676389],
#  [(1, 7, 1, 1), 15637.047159193457],
#  [(1, 7, 1, 2), 15637.89527166784],
#  [(1, 7, 1, 3), 15639.892431187076],
#  [(1, 7, 1, 4), 15641.00182529175],
#  [(1, 7, 2, 0), 15708.50066242329],
#  [(1, 7, 2, 1), 15638.860103141455],
#  [(1, 7, 2, 2), 15640.05137598188],
#  [(1, 7, 2, 3), 15641.672102983726],
#  [(1, 7, 2, 4), 15642.754525519464],
#  [(1, 7, 3, 0), 15673.030886427627],
#  [(1, 7, 3, 1), 15639.408335836999],
#  [(1, 7, 3, 2), 15640.98044141294],
#  [(1, 7, 3, 3), 15642.829491914088],
#  [(1, 7, 3, 4), 15643.70852620257],
#  [(1, 7, 4, 0), 15659.7941099021],
#  [(1, 7, 4, 1), 15640.536618843846],
#  [(1, 7, 4, 2), 15642.293332042022],
#  [(1, 7, 4, 3), 15644.77032717605],
#  [(1, 7, 4, 4), 15645.900052698309],
#  [(1, 8, 0, 0), 15930.927949643165],
#  [(1, 8, 0, 1), 15638.404765096053],
#  [(1, 8, 0, 2), 15637.645705452342],
#  [(1, 8, 0, 3), 15639.509152790215],
#  [(1, 8, 0, 4), 15640.379193092438],
#  [(1, 8, 1, 0), 15744.411088547658],
#  [(1, 8, 1, 1), 15637.503586310186],
#  [(1, 8, 1, 2), 15638.316576134575],
#  [(1, 8, 1, 3), 15640.317722345895],
#  [(1, 8, 1, 4), 15644.322944614116],
#  [(1, 8, 2, 0), 15709.372934980673],
#  [(1, 8, 2, 1), 15641.880335925262],
#  [(1, 8, 2, 2), 15640.30921757381],
#  [(1, 8, 2, 3), 15630.851287640735],
#  [(1, 8, 2, 4), 15631.859150515296],
#  [(1, 8, 3, 0), 15673.655381306668],
#  [(1, 8, 3, 1), 15641.833500028795],
#  [(1, 8, 3, 2), 15643.236080538103],
#  [(1, 8, 3, 3), 15644.520086996767],
#  [(1, 8, 3, 4), 15645.01603962816],
#  [(1, 8, 4, 0), 15660.39065623637],
#  [(1, 8, 4, 1), 15640.974649399024],
#  [(1, 8, 4, 2), 15642.857790162567],
#  [(1, 8, 4, 3), 15635.975220054022],
#  [(1, 8, 4, 4), 15647.345302139423],
#  [(1, 9, 0, 0), 15856.256067350807],
#  [(1, 9, 0, 1), 15631.069738412698],
#  [(1, 9, 0, 2), 15631.125805021205],
#  [(1, 9, 0, 3), 15632.990683933003],
#  [(1, 9, 0, 4), 15633.94834731613],
#  [(1, 9, 1, 0), 15732.668305767229],
#  [(1, 9, 1, 1), 15631.027729036174],
#  [(1, 9, 1, 2), 15631.894999577838],
#  [(1, 9, 1, 3), 15633.893205093827],
#  [(1, 9, 1, 4), 15635.099357551364],
#  [(1, 9, 2, 0), 15699.605380021518],
#  [(1, 9, 2, 1), 15632.827302469263],
#  [(1, 9, 2, 2), 15633.89347268708],
#  [(1, 9, 2, 3), 15633.806943845593],
#  [(1, 9, 2, 4), 15636.960424061526],
#  [(1, 9, 3, 0), 15666.31517568772],
#  [(1, 9, 3, 1), 15633.515491619433],
#  [(1, 9, 3, 2), 15635.087410688253],
#  [(1, 9, 3, 3), 15636.988972073646],
#  [(1, 9, 3, 4), 15638.970616144808],
#  [(1, 9, 4, 0), 15653.841585361119],
#  [(1, 9, 4, 1), 15634.70656344097],
#  [(1, 9, 4, 2), 15636.493297952871],
#  [(1, 9, 4, 3), 15638.629243546891],
#  [(1, 9, 4, 4), 15640.37942353348],
#  [(1, 10, 0, 0), 15854.54026055359],
#  [(1, 10, 0, 1), 15634.34396560078],
#  [(1, 10, 0, 2), 15634.433099159065],
#  [(1, 10, 0, 3), 15636.296247979659],
#  [(1, 10, 0, 4), 15637.251736111277],
#  [(1, 10, 1, 0), 15734.696540378196],
#  [(1, 10, 1, 1), 15634.331477220781],
#  [(1, 10, 1, 2), 15635.186437957193],
#  [(1, 10, 1, 3), 15637.185163703012],
#  [(1, 10, 1, 4), 15638.385443625652],
#  [(1, 10, 2, 0), 15701.947206951061],
#  [(1, 10, 2, 1), 15636.128457418816],
#  [(1, 10, 2, 2), 15637.185455788074],
#  [(1, 10, 2, 3), 15638.897232658099],
#  [(1, 10, 2, 4), 15640.176976603227],
#  [(1, 10, 3, 0), 15669.43570498838],
#  [(1, 10, 3, 1), 15636.807137232478],
#  [(1, 10, 3, 2), 15638.374488261052],
#  [(1, 10, 3, 3), 15640.261562573134],
#  [(1, 10, 3, 4), 15631.455387499493],
#  [(1, 10, 4, 0), 15657.04111534638],
#  [(1, 10, 4, 1), 15637.989221147034],
#  [(1, 10, 4, 2), 15639.781472192144],
#  [(1, 10, 4, 3), 15642.190741863487],
#  [(1, 10, 4, 4), 15643.947189357072],
#  [(1, 11, 0, 0), 15784.892025912031],
#  [(1, 11, 0, 1), 15640.026632902356],
#  [(1, 11, 0, 2), 15640.62194981074],
#  [(1, 11, 0, 3), 15642.487518179825],
#  [(1, 11, 0, 4), 15643.460871331717],
#  [(1, 11, 1, 0), 15733.157597147423],
#  [(1, 11, 1, 1), 15640.532740289626],
#  [(1, 11, 1, 2), 15641.41065615842],
#  [(1, 11, 1, 3), 15643.405914500752],
#  [(1, 11, 1, 4), 15644.622705574888],
#  [(1, 11, 2, 0), 15705.08174357974],
#  [(1, 11, 2, 1), 15642.331874347085],
#  [(1, 11, 2, 2), 15643.406894726526],
#  [(1, 11, 2, 3), 15644.625609472441],
#  [(1, 11, 2, 4), 15646.41196829622],
#  [(1, 11, 3, 0), 15674.599928990854],
#  [(1, 11, 3, 1), 15643.043109579285],
#  [(1, 11, 3, 2), 15644.614846447654],
#  [(1, 11, 3, 3), 15646.502315900128],
#  [(2, 2, 1, 0), 15770.757361989605],
#  [(2, 2, 1, 1), 15660.51385204088],
#  [(2, 2, 1, 2), 15660.290686481143],
#  [(2, 2, 1, 3), 15662.282038612022],
#  [(2, 2, 1, 4), 15663.121589306607],
#  [(2, 2, 2, 0), 15735.827969860347],
#  [(2, 2, 2, 1), 15661.928632522839],
#  [(2, 2, 2, 2), 15662.28366947452],
#  [(2, 2, 2, 3), 15649.837392537756],
#  [(2, 2, 2, 4), 15652.245773924566],
#  [(2, 2, 3, 0), 15694.952285797546],
#  [(2, 2, 3, 1), 15661.800083396367],
#  [(2, 2, 3, 2), 15663.123958494312],
#  [(2, 2, 3, 3), 15664.895925200242],
#  [(2, 2, 3, 4), 15666.654787991627],
#  [(2, 2, 4, 0), 15681.836999838115],
#  [(2, 2, 4, 1), 15662.650427826931],
#  [(2, 2, 4, 2), 15664.3819300823],
#  [(2, 2, 4, 3), 15656.65547077369],
#  [(2, 2, 4, 4), 15668.264570561358],
#  [(2, 3, 0, 0), 15886.544827757993],
#  [(2, 3, 0, 1), 15621.023038129762],
#  [(2, 3, 0, 2), 15658.288592166342],
#  [(2, 3, 0, 3), 15657.470392995725],
#  [(2, 3, 0, 4), 15660.312401391475],
#  [(2, 3, 1, 0), 15752.751261457213],
#  [(2, 3, 1, 1), 15657.853936615611],
#  [(2, 3, 1, 2), 15657.707589592803],
#  [(2, 3, 1, 3), 15659.699723939731],
#  [(2, 3, 1, 4), 15660.584838004437],
#  [(2, 3, 2, 0), 15734.447275129009],
#  [(2, 3, 2, 1), 15659.319641574262],
#  [(2, 3, 2, 2), 15659.700281384194],
#  [(2, 3, 2, 3), 15646.446271326298],
#  [(2, 3, 2, 4), 15648.509078520616],
#  [(2, 3, 3, 0), 15692.949482472552],
#  [(2, 3, 3, 1), 15659.219437937661],
#  [(2, 3, 3, 2), 15660.590855295388],
#  [(2, 3, 3, 3), 15662.37599092368],
#  [(2, 3, 3, 4), 15664.364262444102],
#  [(2, 3, 4, 0), 15679.623598382077],
#  [(2, 3, 4, 1), 15660.061091291707],
#  [(2, 3, 4, 2), 15661.84353326902],
#  [(2, 3, 4, 3), 15649.381228712464],
#  [(2, 3, 4, 4), 15665.829109632148],
#  [(2, 4, 0, 0), 15977.146647675732],
#  [(2, 4, 0, 1), 15662.133602806754],
#  [(2, 4, 0, 2), 15658.589945944694],
#  [(2, 4, 0, 3), 15657.433040338987],
#  [(2, 4, 0, 4), 15657.563737927896],
#  [(2, 4, 1, 0), 15753.364563274368],
#  [(2, 4, 1, 1), 15655.561214136898],
#  [(2, 4, 1, 2), 15655.911324612793],
#  [(2, 4, 1, 3), 15657.92332644136],
#  [(2, 4, 1, 4), 15658.908249346425],
#  [(2, 4, 2, 0), 15734.575949386068],
#  [(2, 4, 2, 1), 15656.440017351935],
#  [(2, 4, 2, 2), 15657.907674800117],
#  [(2, 4, 2, 3), 15646.43848821607],
#  [(2, 4, 2, 4), 15649.15017299038],
#  [(2, 4, 3, 0), 15687.118742640198],
#  [(2, 4, 3, 1), 15657.505462789806],
#  [(2, 4, 3, 2), 15658.957282862897],
#  [(2, 4, 3, 3), 15662.182552333858],
#  [(2, 4, 3, 4), 15651.051909704653],
#  [(2, 4, 4, 0), 15674.549814249804],
#  [(2, 4, 4, 1), 15658.318388789241],
#  [(2, 4, 4, 2), 15660.212286392874],
#  [(2, 4, 4, 3), 15651.063265288385],
#  [(2, 4, 4, 4), 15653.847221964887],
#  [(2, 5, 0, 0), 15992.305365481237],
#  [(2, 5, 0, 1), 15656.809485799804],
#  [(2, 5, 0, 2), 15651.687951045145],
#  [(2, 5, 0, 3), 15653.418898589302],
#  [(2, 5, 0, 4), 15654.296712968711],
#  [(2, 5, 1, 0), 15753.176568459972],
#  [(2, 5, 1, 1), 15651.299613899326],
#  [(2, 5, 1, 2), 15651.975882472636],
#  [(2, 5, 1, 3), 15653.728942594687],
#  [(2, 5, 1, 4), 15654.79900444926],
#  [(2, 5, 2, 0), 15730.291690099151],
#  [(2, 5, 2, 1), 15653.051275233618],
#  [(2, 5, 2, 2), 15654.2875920056],
#  [(2, 5, 2, 3), 15655.874671905673],
#  [(2, 5, 2, 4), 15655.542663391734],
#  [(2, 5, 3, 0), 15686.204182515852],
#  [(2, 5, 3, 1), 15653.17211287723],
#  [(2, 5, 3, 2), 15654.57686753971],
#  [(2, 5, 3, 3), 15656.509169376612],
#  [(2, 5, 3, 4), 15655.590481229105],
#  [(2, 5, 4, 0), 15674.425149002021],
#  [(2, 5, 4, 1), 15654.157441247928],
#  [(2, 5, 4, 2), 15658.031061877507],
#  [(2, 5, 4, 3), 15658.42198241728],
#  [(2, 5, 4, 4), 15658.8782824272],
#  [(2, 6, 0, 0), 15967.898055780239],
#  [(2, 6, 0, 1), 15636.815127766284],
#  [(2, 6, 0, 2), 15644.200304563285],
#  [(2, 6, 0, 3), 15645.993331375488],
#  [(2, 6, 0, 4), 15646.569190051414],
#  [(2, 6, 1, 0), 15745.02659200582],
#  [(2, 6, 1, 1), 15644.067465379792],
#  [(2, 6, 1, 2), 15644.359327269573],
#  [(2, 6, 1, 3), 15646.355549201911],
#  [(2, 6, 1, 4), 15647.241745401452],
#  [(2, 6, 2, 0), 15713.003822241299],
#  [(2, 6, 2, 1), 15643.524441319812],
#  [(2, 6, 2, 2), 15646.351694207977],
#  [(2, 6, 2, 3), 15642.089600277786],
#  [(2, 6, 2, 4), 15648.057699054263],
#  [(2, 6, 3, 0), 15679.70375382145],
#  [(2, 6, 3, 1), 15643.6168893613],
#  [(2, 6, 3, 2), 15647.22577336427],
#  [(2, 6, 3, 3), 15649.071180128956],
#  [(2, 6, 3, 4), 15650.98940917116]]

# %%
len(results)
#обработал только 1/4, а времени потратил 12 часов...
#Лучше построю модель из того, что есть
# Out:
# 770

# %%
import csv

writer = csv.writer(open("results.csv", 'w', newline = ''))
columns = ['ps', 'qs', 'Ps', 'Qs', 'aic']
writer.writerow(columns)
for row in results:
    arr = []
    arr.append(int(row[0][0]))
    arr.append(int(row[0][1]))
    arr.append(int(row[0][2]))
    arr.append(int(row[0][3]))
    arr.append(row[1])
    writer.writerow(arr)

# %%
ndf = pd.read_csv('results.csv')
ndf = ndf.dropna()
ndf.isna().sum()

# %%
ndf['ps'] = ndf['ps'].astype(int)
ndf['Qs'] = ndf['Qs'].astype(int)
ndf
# Out:
#      ps  qs  Ps  Qs           aic
# 0     0   0   0   0  16065.759338
# 1     0   0   0   1  15585.537635
# 2     0   0   0   2  15619.386875
# 3     0   0   0   3  15586.842978
# 4     0   0   0   4  15632.194511
# ..   ..  ..  ..  ..           ...
# 765   2   6   3   0  15679.703754
# 766   2   6   3   1  15643.616889
# 767   2   6   3   2  15647.225773
# 768   2   6   3   3  15649.071180
# 769   2   6   3   4  15650.989409
#
# [769 rows x 5 columns]

# %%
print('best aic: {}, best model: {}, best param: {}'.format(best_aic, best_model, best_param))
# Out:
# best aic: 15533.168503411216, best model: <statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper object at 0x00000167064D1A48>, best param: (1, 0, 0, 3)

# %%
plt.figure(figsize(15,8))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print(" Критерий —Стьюдента: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
#  Критерий —Стьюдента: p=0.031627
#  Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# При проверке гипотез используют критерий Стьюдента, по нему можно судить о том, верно предоположение или нет.
#
# Примерная интерпритация:
#
# ≥0,1Данные согласуются с нулевой гипотезой (H0), различия не подтверждены
#
# #### ≥0,05Есть сомнения в истинности как нулевой (H0), так и альтернативной гипотез (H1)<0,05 Нулевая гипотеза (H0) может быть отвергнута.
#
# ≤0,01Нулевая гипотеза (H0) может быть отвергнута. Сильный аргумент
#
# ≤0,001Нулевая гипотеза (H0) наверняка не подтверждается. Очень сильный аргумент

# %% [markdown]
# Остатки СМЕЩЕНЫ (подтверждается критерием —Стьюдента) СТАЦИОНАРНЫ (подтверждается критерием Дики-Фуллера и визуально), неавтокоррелированы (подтверждается критерием Тьюнга-Кокса и коррелограммой). ѕосмотрим, насколько хорошо модель описывает данные:

# %%
df['model'] = invboxcox(best_model.fittedvalues, lmbda)
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
df.model[0:].plot(color='r')
plt.ylabel('DUQ_MW')
pylab.show()

# %%
df2 = df[['DUQ_MW']]
date_list = [datetime.datetime.strptime("2005-09-01", "%Y-%m-%d") + relativedelta(months=x) for x in range(0,5)]
future = pd.DataFrame(index=date_list, columns= df2.columns)
df2 = pd.concat([df2, future])
df2['forecast'] = invboxcox(best_model.predict(start=0, end=1500), lmbda)

plt.figure(figsize(15,7))
df2.plot()
df2.forecast.plot(color='r')
plt.ylabel('DUQ_MW')
pylab.show()

# %% [markdown]
# Выглядит хорошо, дисперсия не увеличивается, есть дельта, но прогнозу не мешает. Остатки стационарны, значит дельта в прогнозе не мешает отслеживанию реальных данных.
